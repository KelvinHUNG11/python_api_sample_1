# %%
# !pip install openpyxl
import pandas as pd
test=pd.read_excel('../dataset/Date_Fruit_Datasets_test.csv')
test.dropna(axis=0, how='any')
test.head()
# Out:
# ...
#      AREA  PERIMETER  MAJOR_AXIS  MINOR_AXIS ECCENTRICITY   EQDIASQ  SOLIDITY  \
# 0  422163   2378.908    837.8484    645.6693       0.6373  733.1539    0.9947
# 1  338136   2085.144    723.8198    595.2073         N.A.  656.1464    0.9974
# 2  526843   2647.394    940.7379    715.3638       0.6494  819.0222    0.9962
# 3  416063   2351.210    827.9804    645.2988       0.6266  727.8378    0.9948
# 4  347562   2160.354    763.9877    582.8359       0.6465  665.2291    0.9908
#
#    CONVEX_AREA  EXTENT  ASPECT_RATIO  ...  KurtosisRR  KurtosisRG  KurtosisRB  \
# 0       424428  0.7831        1.2976  ...      3.2370      2.9574      4.2287
# 1       339014  0.7795        1.2161  ...      2.6228      2.6350      3.1704
# 2       528876  0.7657        1.3150  ...      3.7516      3.8611      4.7192
# 3       418255  0.7759        1.2831  ...      5.0401      8.6136      8.2618
# 4       350797  0.7569        1.3108  ...      2.7016      2.9761      4.4146
#
# ...

# %%
## Optional, to reload the trained ML model
import pickle
automl = pickle.load(open('automl.pkl', 'rb'))

y_pred = automl.predict(test)
y_pred[:200]
# Out:
# array(['BERHI', 'BERHI', 'BERHI', 'IRAQI', 'BERHI', 'DEGLET', 'DEGLET',
#        'DEGLET', 'DEGLET', 'DEGLET', 'DOKOL', 'DOKOL', 'DOKOL', 'DOKOL',
#        'DOKOL', 'IRAQI', 'IRAQI', 'IRAQI', 'IRAQI', 'IRAQI', 'ROTANA',
#        'ROTANA', 'ROTANA', 'ROTANA', 'ROTANA', 'SAFAVI', 'SAFAVI',
#        'SAFAVI', 'SAFAVI', 'SAFAVI', 'SOGAY', 'ROTANA', 'SOGAY', 'SOGAY',
#        'SOGAY'], dtype=object)

# %%
for i in range(len(y_pred)):
    # updating the column value/data
    test.loc[i, 'Class'] = y_pred[i]
  
# writing into the file
test.to_csv("../dataset/Date_Fruit_Datasets_test.csv", index=False)
